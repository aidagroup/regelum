# %%
from regelum.environment.node.base import Node, State, Inputs, MPCNodeFactory
from regelum.environment.graph import Graph
import numpy as np
from regelum.utils import rg
import logging
from typing import Dict, Any
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from stable_baselines3.common.buffers import ReplayBuffer
import gymnasium as gym
import torch.optim as optim
from typing import Optional
from IPython.display import clear_output

logging.basicConfig(
    level=logging.INFO, format="%(asctime)s - %(name)s - %(levelname)s - %(message)s"
)

# %% [markdown]
# ## Pendulum PD controller

# %% [markdown]
# # ![Pendulum PD Controller|width=3.67%](./gfx/pd.png)

# %%
class Pendulum(Node):
    state = State("pendulum_state", (2,), np.array([np.pi, 0]))
    inputs = Inputs(
        ["pendulum_pd_control", "reset_pendulum_state"]
    )  ### reset_... is a service input
    length = 1
    mass = 1
    gravity_acceleration = 9.81

    def system_dynamics(self, x, u):
        pendulum_mpc_control = u

        angle = x[0]
        angular_velocity = x[1]
        torque = pendulum_mpc_control

        d_angle = angular_velocity
        d_angular_velocity = self.gravity_acceleration / (self.length) * rg.sin(
            angle
        ) + torque / (self.mass * self.length**2)

        return {"pendulum_state": rg.vstack([d_angle, d_angular_velocity])}

    def compute_state_dynamics(self):
        pendulum_mpc_control = self.inputs["pendulum_pd_control"].data

        return self.system_dynamics(self.state.data, pendulum_mpc_control)

# %%
class PendulumPDController(Node):
    state = State("pendulum_pd_control", (1,))
    inputs = Inputs(["pendulum_state"])

    def __init__(self, kp: float = 0.01, kd: float = 0.01, step_size: float = 0.01):
        super().__init__(step_size=step_size)
        self.kp = kp
        self.kd = kd

    def compute_state_dynamics(self):
        pendulum_state = self.inputs["pendulum_state"].data

        angle = pendulum_state[0]
        angular_velocity = pendulum_state[1]

        return {"pendulum_pd_control": -self.kp * angle - self.kd * angular_velocity}

# %%
class IsTruncated(Node):
    def __init__(self, steps_to_truncate: int, **kwargs):
        state = State("is_truncated", (1,), False)
        inputs = ["step_counter"]
        self.steps_to_truncate = steps_to_truncate
        super().__init__(state=state, inputs=inputs, **kwargs)

    def compute_state_dynamics(self) -> Dict[str, Any]:
        residual = self.inputs["step_counter"].data[0] % self.steps_to_truncate
        return {self.state.name: residual == 0}


class Reset(Node):
    def __init__(self, input_node: Node, **kwargs):
        state = State(f"reset_{input_node.state.name}", (1,), False)
        inputs = ["is_truncated"]
        super().__init__(state=state, inputs=inputs, **kwargs)

    def compute_state_dynamics(self) -> Dict[str, Any]:
        return {self.state.name: self.inputs["is_truncated"].data}

# %%
class PlotDumper(Node):
    def __init__(self, **kwargs):
        state = State("plot_dumper", (1,), False)
        inputs = ["pendulum_state", "pendulum_pd_control", "reset_pendulum_state"]
        super().__init__(state=state, inputs=inputs, **kwargs)
        self.states = []
        self.controls = []

    def compute_state_dynamics(self) -> Dict[str, Any]:
        self.states.append(self.inputs["pendulum_state"].data)
        self.controls.append(self.inputs["pendulum_pd_control"].data)

        if self.inputs["reset_pendulum_state"].data:
            self._plot()
            self.states = []
            self.controls = []

        return {self.state.name: False}

    def _plot(self) -> None:
        fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))

        states = np.array(self.states)
        controls = np.array(self.controls)
        times = np.arange(len(states)) * self.step_size

        ax1.plot(times, states[:, 0], label="angle")
        ax1.plot(times, states[:, 1], label="angular velocity")
        ax1.set_ylabel("State")
        ax1.legend()

        ax2.plot(times, controls, label="control")
        ax2.set_xlabel("Time [s]")
        ax2.set_ylabel("Control")
        ax2.legend()

        plt.show()

# %%
n_steps = 1000
pd_controller = PendulumPDController(20, 20, step_size=0.01)
pendulum = Pendulum(is_root=True, is_continuous=True)
is_truncated = IsTruncated(steps_to_truncate=1000)
reset = Reset(pendulum)
plot_dumper = PlotDumper()
graph = Graph(
    [pd_controller, pendulum, is_truncated, reset, plot_dumper],
    states_to_log=["pendulum_state", "pendulum_pd_control"],
    logger_cooldown=0.5,
)
# Out:
# Resolved node order: pendulum_state -> Clock -> step_counter -> pendulum_pd_control -> is_truncated -> reset_pendulum_state -> Logger -> plot_dumper

# %%
for _ in range(n_steps):
    graph.step()

graph.reset()
# Out:
# 2024-12-04 17:16:18,775 - t=337.610 | pendulum_state=[3.142 0.   ] | pendulum_pd_control=-62.832
# 2024-12-04 17:16:18,849 - t=338.120 | pendulum_state=[ 2.027 -1.698] | pendulum_pd_control=-6.587
# 2024-12-04 17:16:18,895 - t=338.630 | pendulum_state=[ 1.381 -0.946] | pendulum_pd_control=-8.706
# 2024-12-04 17:16:18,952 - t=339.140 | pendulum_state=[ 0.995 -0.608] | pendulum_pd_control=-7.742
# 2024-12-04 17:16:18,999 - t=339.650 | pendulum_state=[ 0.736 -0.422] | pendulum_pd_control=-6.293
# 2024-12-04 17:16:19,048 - t=340.160 | pendulum_state=[ 0.553 -0.305] | pendulum_pd_control=-4.956
# 2024-12-04 17:16:19,092 - t=340.670 | pendulum_state=[ 0.419 -0.226] | pendulum_pd_control=-3.850
# 2024-12-04 17:16:19,144 - t=341.180 | pendulum_state=[ 0.319 -0.17 ] | pendulum_pd_control=-2.971
# 2024-12-04 17:16:19,191 - t=341.690 | pendulum_state=[ 0.243 -0.129] | pendulum_pd_control=-2.284
# 2024-12-04 17:16:19,239 - t=342.200 | pendulum_state=[ 0.185 -0.098] | pendulum_pd_control=-1.752
# 2024-12-04 17:16:19,288 - t=342.710 | pendulum_state=[ 0.142 -0.075] | pendulum_pd_control=-1.343
# 2024-12-04 17:16:19,341 - t=343.220 | pendulum_state=[ 0.108 -0.057] | pendulum_pd_control=-1.029
# 2024-12-04 17:16:19,389 - t=343.730 | pendulum_state=[ 0.083 -0.044] | pendulum_pd_control=-0.788
# 2024-12-04 17:16:19,437 - t=344.240 | pendulum_state=[ 0.063 -0.033] | pendulum_pd_control=-0.603
# 2024-12-04 17:16:19,487 - t=344.750 | pendulum_state=[ 0.049 -0.025] | pendulum_pd_control=-0.462
# 2024-12-04 17:16:19,537 - t=345.260 | pendulum_state=[ 0.037 -0.019] | pendulum_pd_control=-0.353
# 2024-12-04 17:16:19,584 - t=345.770 | pendulum_state=[ 0.028 -0.015] | pendulum_pd_control=-0.270
# 2024-12-04 17:16:19,635 - t=346.280 | pendulum_state=[ 0.022 -0.011] | pendulum_pd_control=-0.207
# 2024-12-04 17:16:19,690 - t=346.790 | pendulum_state=[ 0.017 -0.009] | pendulum_pd_control=-0.158
# 2024-12-04 17:16:19,752 - t=347.300 | pendulum_state=[ 0.013 -0.007] | pendulum_pd_control=-0.121

# %% [markdown]
# ## MPC controller

# %%
class Pendulum(Node):
    state = State("pendulum_state", (2,), np.array([np.pi, 0]))
    inputs = Inputs(["mpc_pendulum_state_control", "reset_pendulum_state"])
    length = 1
    mass = 1
    gravity_acceleration = 9.81

    def system_dynamics(self, x, u):
        pendulum_mpc_control = u

        angle = x[0]
        angular_velocity = x[1]
        torque = pendulum_mpc_control

        d_angle = angular_velocity
        d_angular_velocity = (
            -3 * self.gravity_acceleration / (2 * self.length) * rg.sin(angle)
            + torque / self.mass
        )

        return {"pendulum_state": rg.vstack([d_angle, d_angular_velocity])}

    def compute_state_dynamics(self):
        pendulum_mpc_control = self.inputs["mpc_pendulum_state_control"].data

        return self.system_dynamics(self.state.data, pendulum_mpc_control)

# %%
class IsTruncated(Node):
    def __init__(self, steps_to_truncate: int, **kwargs):
        state = State("is_truncated", (1,), False)
        inputs = ["step_counter"]
        self.steps_to_truncate = steps_to_truncate
        super().__init__(state=state, inputs=inputs, **kwargs)

    def compute_state_dynamics(self) -> Dict[str, Any]:
        residual = self.inputs["step_counter"].data[0] % self.steps_to_truncate
        return {self.state.name: residual == 0}


class Reset(Node):
    def __init__(self, input_node: Node, **kwargs):
        state = State(f"reset_{input_node.state.name}", (1,), False)
        inputs = ["is_truncated"]
        super().__init__(state=state, inputs=inputs, **kwargs)

    def compute_state_dynamics(self) -> Dict[str, Any]:
        return {self.state.name: self.inputs["is_truncated"].data}

# %%
class PlotDumper(Node):
    def __init__(self, **kwargs):
        state = State("plot_dumper", (1,), False)
        inputs = [
            "pendulum_state",
            "mpc_pendulum_state_control",
            "reset_pendulum_state",
        ]
        super().__init__(state=state, inputs=inputs, **kwargs)
        self.states = []
        self.controls = []

    def compute_state_dynamics(self) -> Dict[str, Any]:
        self.states.append(self.inputs["pendulum_state"].data)
        self.controls.append(self.inputs["mpc_pendulum_state_control"].data)

        if self.inputs["reset_pendulum_state"].data:
            self._plot()
            self.states = []
            self.controls = []

        return {self.state.name: False}

    def _plot(self) -> None:
        fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))

        states = np.array(self.states)
        controls = np.array(self.controls)
        times = np.arange(len(states)) * self.step_size

        ax1.plot(times, states[:, 0], label="angle")
        ax1.plot(times, states[:, 1], label="angular velocity")
        ax1.set_ylabel("State")
        ax1.legend()

        ax2.plot(times, controls, label="control")
        ax2.set_xlabel("Time [s]")
        ax2.set_ylabel("Control")
        ax2.legend()

        plt.show()

# %%
pendulum = Pendulum(is_root=True, is_continuous=True)
mpc_node = MPCNodeFactory(
    pendulum, control_shape=1, prediction_horizon=4, step_size=0.1
)
is_truncated = IsTruncated(steps_to_truncate=1000)
reset = Reset(pendulum)
plot_dumper = PlotDumper()
graph = Graph(
    [mpc_node, pendulum, is_truncated, reset, plot_dumper],
    states_to_log=["pendulum_state", "mpc_pendulum_state_control", "step_counter"],
    logger_cooldown=1.5,
)
# Out:
# Resolved node order: pendulum_state -> Clock -> step_counter -> mpc_pendulum_state_control -> is_truncated -> reset_pendulum_state -> Logger -> plot_dumper

# %%
n_steps = 1000

for _ in range(n_steps):
    graph.step()

graph.reset()
# Out:
# 2024-12-04 17:16:53,320 - t=0.100 | pendulum_state=[3.142 0.   ] | mpc_pendulum_state_control=-2.756 | step_counter=[1]
# 2024-12-04 17:16:53,404 - t=1.600 | pendulum_state=[ 2.536 -0.432] | mpc_pendulum_state_control=8.636 | step_counter=[16]
# 2024-12-04 17:16:53,476 - t=3.100 | pendulum_state=[ 1.899 -0.426] | mpc_pendulum_state_control=14.035 | step_counter=[31]
# 2024-12-04 17:16:53,522 - t=4.700 | pendulum_state=[ 1.241 -0.384] | mpc_pendulum_state_control=13.882 | step_counter=[47]
# 2024-12-04 17:16:53,576 - t=6.300 | pendulum_state=[ 0.71  -0.268] | mpc_pendulum_state_control=9.524 | step_counter=[63]
# 2024-12-04 17:16:53,631 - t=7.900 | pendulum_state=[ 0.375 -0.153] | mpc_pendulum_state_control=5.347 | step_counter=[79]
# 2024-12-04 17:16:53,686 - t=9.500 | pendulum_state=[ 0.193 -0.08 ] | mpc_pendulum_state_control=2.791 | step_counter=[95]
# 2024-12-04 17:16:53,734 - t=11.100 | pendulum_state=[ 0.098 -0.041] | mpc_pendulum_state_control=1.427 | step_counter=[111]
# 2024-12-04 17:16:53,786 - t=12.700 | pendulum_state=[ 0.05  -0.021] | mpc_pendulum_state_control=0.725 | step_counter=[127]
# 2024-12-04 17:16:53,834 - t=14.300 | pendulum_state=[ 0.025 -0.011] | mpc_pendulum_state_control=0.368 | step_counter=[143]
# 2024-12-04 17:16:53,887 - t=15.900 | pendulum_state=[ 0.013 -0.005] | mpc_pendulum_state_control=0.187 | step_counter=[159]
# 2024-12-04 17:16:53,938 - t=17.400 | pendulum_state=[ 0.007 -0.003] | mpc_pendulum_state_control=0.099 | step_counter=[174]
# 2024-12-04 17:16:53,988 - t=18.900 | pendulum_state=[ 0.004 -0.002] | mpc_pendulum_state_control=0.052 | step_counter=[189]
# 2024-12-04 17:16:54,035 - t=20.400 | pendulum_state=[ 0.002 -0.001] | mpc_pendulum_state_control=0.028 | step_counter=[204]
# 2024-12-04 17:16:54,082 - t=21.900 | pendulum_state=[ 0.001 -0.   ] | mpc_pendulum_state_control=0.015 | step_counter=[219]
# 2024-12-04 17:16:54,124 - t=23.400 | pendulum_state=[ 0.001 -0.   ] | mpc_pendulum_state_control=0.008 | step_counter=[234]
# 2024-12-04 17:16:54,178 - t=24.900 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.004 | step_counter=[249]
# 2024-12-04 17:16:54,215 - t=26.400 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.002 | step_counter=[264]
# 2024-12-04 17:16:54,256 - t=27.900 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.001 | step_counter=[279]
# 2024-12-04 17:16:54,292 - t=29.400 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.001 | step_counter=[294]
# 2024-12-04 17:16:54,329 - t=30.900 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[309]
# 2024-12-04 17:16:54,368 - t=32.400 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[324]
# 2024-12-04 17:16:54,407 - t=33.900 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[339]
# 2024-12-04 17:16:54,449 - t=35.400 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[354]
# 2024-12-04 17:16:54,486 - t=36.900 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[369]
# 2024-12-04 17:16:54,521 - t=38.400 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[384]
# 2024-12-04 17:16:54,561 - t=39.900 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[399]
# 2024-12-04 17:16:54,597 - t=41.400 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[414]
# 2024-12-04 17:16:54,632 - t=42.900 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[429]
# 2024-12-04 17:16:54,665 - t=44.400 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[444]
# 2024-12-04 17:16:54,704 - t=45.900 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[459]
# 2024-12-04 17:16:54,749 - t=47.400 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[474]
# 2024-12-04 17:16:54,794 - t=48.900 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[489]
# 2024-12-04 17:16:54,827 - t=50.400 | pendulum_state=[-0.  0.] | mpc_pendulum_state_control=0.000 | step_counter=[504]
# 2024-12-04 17:16:54,855 - t=51.900 | pendulum_state=[-0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[519]
# 2024-12-04 17:16:54,888 - t=53.400 | pendulum_state=[-0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[534]
# 2024-12-04 17:16:54,919 - t=54.900 | pendulum_state=[-0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[549]
# 2024-12-04 17:16:54,956 - t=56.400 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[564]
# 2024-12-04 17:16:54,994 - t=57.900 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[579]
# 2024-12-04 17:16:55,033 - t=59.400 | pendulum_state=[0. 0.] | mpc_pendulum_state_control=0.000 | step_counter=[594]
# 2024-12-04 17:16:55,068 - t=60.900 | pendulum_state=[0. 0.] | mpc_pendulum_state_control=0.000 | step_counter=[609]
# 2024-12-04 17:16:55,102 - t=62.400 | pendulum_state=[0. 0.] | mpc_pendulum_state_control=0.000 | step_counter=[624]
# 2024-12-04 17:16:55,136 - t=63.900 | pendulum_state=[-0.  0.] | mpc_pendulum_state_control=0.000 | step_counter=[639]
# 2024-12-04 17:16:55,174 - t=65.500 | pendulum_state=[-0.  0.] | mpc_pendulum_state_control=0.000 | step_counter=[655]
# 2024-12-04 17:16:55,204 - t=67.100 | pendulum_state=[-0.  0.] | mpc_pendulum_state_control=0.000 | step_counter=[671]
# 2024-12-04 17:16:55,234 - t=68.700 | pendulum_state=[-0.  0.] | mpc_pendulum_state_control=0.000 | step_counter=[687]
# 2024-12-04 17:16:55,268 - t=70.300 | pendulum_state=[-0.  0.] | mpc_pendulum_state_control=0.000 | step_counter=[703]
# 2024-12-04 17:16:55,308 - t=71.900 | pendulum_state=[-0.  0.] | mpc_pendulum_state_control=0.000 | step_counter=[719]
# 2024-12-04 17:16:55,356 - t=73.500 | pendulum_state=[-0.  0.] | mpc_pendulum_state_control=0.000 | step_counter=[735]
# 2024-12-04 17:16:55,399 - t=75.100 | pendulum_state=[-0.  0.] | mpc_pendulum_state_control=0.000 | step_counter=[751]
# 2024-12-04 17:16:55,435 - t=76.700 | pendulum_state=[-0.  0.] | mpc_pendulum_state_control=0.000 | step_counter=[767]
# 2024-12-04 17:16:55,468 - t=78.300 | pendulum_state=[-0.  0.] | mpc_pendulum_state_control=0.000 | step_counter=[783]
# 2024-12-04 17:16:55,500 - t=79.900 | pendulum_state=[-0.  0.] | mpc_pendulum_state_control=0.000 | step_counter=[799]
# 2024-12-04 17:16:55,539 - t=81.500 | pendulum_state=[-0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[815]
# 2024-12-04 17:16:55,581 - t=83.100 | pendulum_state=[-0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[831]
# 2024-12-04 17:16:55,617 - t=84.700 | pendulum_state=[-0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[847]
# 2024-12-04 17:16:55,649 - t=86.300 | pendulum_state=[-0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[863]
# 2024-12-04 17:16:55,684 - t=87.900 | pendulum_state=[-0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[879]
# 2024-12-04 17:16:55,719 - t=89.500 | pendulum_state=[-0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[895]
# 2024-12-04 17:16:55,758 - t=91.100 | pendulum_state=[-0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[911]
# 2024-12-04 17:16:55,797 - t=92.700 | pendulum_state=[-0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[927]
# 2024-12-04 17:16:55,833 - t=94.300 | pendulum_state=[-0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[943]
# 2024-12-04 17:16:55,870 - t=95.900 | pendulum_state=[-0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[959]
# 2024-12-04 17:16:55,908 - t=97.500 | pendulum_state=[-0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[975]
# 2024-12-04 17:16:55,943 - t=99.100 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[991]

# %% [markdown]
# ## MPC control of the multiple envs

# %%
class ThreeWheeledRobotKinematic(Node):
    state = State("robot_state", (3,), np.array([5, -5, 0.8]))  # [x, y, angle]
    inputs = Inputs(["mpc_robot_state_control"])

    def __init__(self, is_root: bool = False, is_continuous: bool = True):
        super().__init__(is_root=is_root, is_continuous=is_continuous)
        self.action_bounds = {
            "mpc_robot_state_control": (
                np.array([-25.0, -5.0]),  # lower bounds
                np.array([25.0, 5.0]),  # upper bounds
            )
        }

    def system_dynamics(self, x: np.ndarray, u: np.ndarray):
        """Compute right-hand side of the dynamic system.

        Args:
            x: Current state [x, y, angle]
            u: Control inputs [velocity, angular_velocity]
        """
        Dstate = rg.zeros((3,), prototype=(x, u))

        # Kinematic model
        Dstate[0] = u[0] * rg.cos(x[2])  # dx/dt = v * cos(theta)
        Dstate[1] = u[0] * rg.sin(x[2])  # dy/dt = v * sin(theta)
        Dstate[2] = u[1]  # dtheta/dt = omega

        return {"robot_state": Dstate}

    def compute_state_dynamics(self):
        robot_control = self.inputs["mpc_robot_state_control"].data
        return self.system_dynamics(self.state.data, robot_control)


class Pendulum(Node):
    state = State("pendulum_state", (2,), np.array([np.pi, 0]))
    inputs = Inputs(["mpc_pendulum_state_control"])
    length = 1
    mass = 1
    gravity_acceleration = 9.81

    def system_dynamics(self, x, u):
        pendulum_mpc_control = u

        angle = x[0]
        angular_velocity = x[1]
        torque = pendulum_mpc_control

        d_angle = angular_velocity
        d_angular_velocity = (
            -3 * self.gravity_acceleration / (2 * self.length) * rg.sin(angle)
            + torque / self.mass
        )

        return {"pendulum_state": rg.vstack([d_angle, d_angular_velocity])}

    def compute_state_dynamics(self):
        pendulum_mpc_control = self.inputs["mpc_pendulum_state_control"].data

        return self.system_dynamics(self.state.data, pendulum_mpc_control)

# %%
class PlotDumper(Node):
    def __init__(self, **kwargs):
        state = State("plot_dumper", (1,), False)
        inputs = [
            "pendulum_state",
            "mpc_pendulum_state_control",
            "robot_state",
            "mpc_robot_state_control",
            "step_counter",
        ]
        super().__init__(state=state, inputs=inputs, **kwargs)
        self.pendulum_states = []
        self.pendulum_controls = []
        self.robot_states = []
        self.robot_controls = []

    def compute_state_dynamics(self) -> Dict[str, Any]:
        self.pendulum_states.append(self.inputs["pendulum_state"].data)
        self.pendulum_controls.append(self.inputs["mpc_pendulum_state_control"].data)
        self.robot_states.append(self.inputs["robot_state"].data)
        self.robot_controls.append(self.inputs["mpc_robot_state_control"].data)

        if self.inputs["step_counter"].data[0] % 500 == 0:
            self._plot()
            self.pendulum_states = []
            self.pendulum_controls = []
            self.robot_states = []
            self.robot_controls = []

        return {self.state.name: False}

    def _plot(self) -> None:
        fig, axs = plt.subplots(4, 1, figsize=(10, 16))

        pendulum_states = np.array(self.pendulum_states)
        pendulum_controls = np.array(self.pendulum_controls)
        robot_states = np.array(self.robot_states)
        robot_controls = np.array(self.robot_controls)
        times = np.arange(len(pendulum_states)) * self.step_size

        axs[0].plot(times, pendulum_states[:, 0], label="Pendulum Angle")
        axs[0].set_ylabel("Pendulum Angle")
        axs[0].legend()

        axs[1].plot(times, pendulum_states[:, 1], label="Pendulum Angular Velocity")
        axs[1].set_ylabel("Pendulum Angular Velocity")
        axs[1].legend()

        axs[2].plot(times, robot_states[:, 0], label="Robot X Position")
        axs[2].plot(times, robot_states[:, 1], label="Robot Y Position")
        axs[2].set_ylabel("Robot Position")
        axs[2].legend()

        axs[3].plot(times, robot_states[:, 2], label="Robot Angle")
        axs[3].set_xlabel("Time [s]")
        axs[3].set_ylabel("Robot Angle")
        axs[3].legend()

        plt.tight_layout()
        plt.show()

# %%
pendulum = Pendulum(is_root=True, is_continuous=True)
robot = ThreeWheeledRobotKinematic(is_root=True, is_continuous=True)
mpc_pendulum_node = MPCNodeFactory(
    pendulum, control_shape=1, prediction_horizon=4, step_size=0.1
)
mpc_robot_node = MPCNodeFactory(
    robot, control_shape=2, prediction_horizon=4, step_size=0.1
)
plot_dumper = PlotDumper()
graph = Graph(
    [mpc_pendulum_node, pendulum, mpc_robot_node, robot, plot_dumper],
    states_to_log=[
        "pendulum_state",
        "mpc_pendulum_state_control",
        "step_counter",
        "robot_state",
        "mpc_robot_state_control",
    ],
    logger_cooldown=0.8,
)
# Out:
# Resolved node order: pendulum_state -> robot_state -> Clock -> step_counter -> mpc_pendulum_state_control -> mpc_robot_state_control -> plot_dumper -> Logger

# %%
n_steps = 500

for _ in range(n_steps):
    graph.step()

graph.reset()
# Out:
# 2024-12-04 17:18:02,178 - t=0.100 | pendulum_state=[3.142 0.   ] | mpc_pendulum_state_control=-2.756 | step_counter=[1] | robot_state=[ 5.  -5.   0.8] | mpc_robot_state_control=[  2.343 -15.253]
# 2024-12-04 17:18:02,260 - t=1.000 | pendulum_state=[ 2.794 -0.438] | mpc_pendulum_state_control=5.319 | step_counter=[10] | robot_state=[ 0.017 -0.754 -0.007] | mpc_robot_state_control=[-0.146  0.021]
# 2024-12-04 17:18:02,312 - t=1.800 | pendulum_state=[ 2.451 -0.43 ] | mpc_pendulum_state_control=9.618 | step_counter=[18] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[-0.  0.]
# 2024-12-04 17:18:02,359 - t=2.600 | pendulum_state=[ 2.111 -0.427] | mpc_pendulum_state_control=12.781 | step_counter=[26] | robot_state=[-0.    -0.753  0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:02,407 - t=3.400 | pendulum_state=[ 1.772 -0.423] | mpc_pendulum_state_control=14.489 | step_counter=[34] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:02,468 - t=4.300 | pendulum_state=[ 1.399 -0.402] | mpc_pendulum_state_control=14.483 | step_counter=[43] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:02,542 - t=5.200 | pendulum_state=[ 1.056 -0.353] | mpc_pendulum_state_control=12.744 | step_counter=[52] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:02,609 - t=6.100 | pendulum_state=[ 0.766 -0.284] | mpc_pendulum_state_control=10.129 | step_counter=[61] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:02,690 - t=7.000 | pendulum_state=[ 0.54  -0.213] | mpc_pendulum_state_control=7.511 | step_counter=[70] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:02,767 - t=7.900 | pendulum_state=[ 0.375 -0.153] | mpc_pendulum_state_control=5.347 | step_counter=[79] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:02,852 - t=8.800 | pendulum_state=[ 0.258 -0.107] | mpc_pendulum_state_control=3.725 | step_counter=[88] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:02,936 - t=9.700 | pendulum_state=[ 0.177 -0.074] | mpc_pendulum_state_control=2.568 | step_counter=[97] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:03,022 - t=10.600 | pendulum_state=[ 0.121 -0.051] | mpc_pendulum_state_control=1.761 | step_counter=[106] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:03,107 - t=11.500 | pendulum_state=[ 0.083 -0.035] | mpc_pendulum_state_control=1.205 | step_counter=[115] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:03,187 - t=12.400 | pendulum_state=[ 0.057 -0.024] | mpc_pendulum_state_control=0.824 | step_counter=[124] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:03,273 - t=13.300 | pendulum_state=[ 0.039 -0.016] | mpc_pendulum_state_control=0.562 | step_counter=[133] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:03,353 - t=14.200 | pendulum_state=[ 0.026 -0.011] | mpc_pendulum_state_control=0.384 | step_counter=[142] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:03,434 - t=15.100 | pendulum_state=[ 0.018 -0.008] | mpc_pendulum_state_control=0.262 | step_counter=[151] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:03,518 - t=16.000 | pendulum_state=[ 0.012 -0.005] | mpc_pendulum_state_control=0.179 | step_counter=[160] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:03,597 - t=16.800 | pendulum_state=[ 0.009 -0.004] | mpc_pendulum_state_control=0.128 | step_counter=[168] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:03,680 - t=17.600 | pendulum_state=[ 0.006 -0.003] | mpc_pendulum_state_control=0.091 | step_counter=[176] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:03,753 - t=18.400 | pendulum_state=[ 0.004 -0.002] | mpc_pendulum_state_control=0.065 | step_counter=[184] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:03,834 - t=19.200 | pendulum_state=[ 0.003 -0.001] | mpc_pendulum_state_control=0.046 | step_counter=[192] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:03,910 - t=20.000 | pendulum_state=[ 0.002 -0.001] | mpc_pendulum_state_control=0.033 | step_counter=[200] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:03,978 - t=20.800 | pendulum_state=[ 0.002 -0.001] | mpc_pendulum_state_control=0.023 | step_counter=[208] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:04,057 - t=21.600 | pendulum_state=[ 0.001 -0.   ] | mpc_pendulum_state_control=0.017 | step_counter=[216] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:04,125 - t=22.400 | pendulum_state=[ 0.001 -0.   ] | mpc_pendulum_state_control=0.012 | step_counter=[224] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:04,198 - t=23.200 | pendulum_state=[ 0.001 -0.   ] | mpc_pendulum_state_control=0.008 | step_counter=[232] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:04,283 - t=24.000 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.006 | step_counter=[240] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:04,354 - t=24.800 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.004 | step_counter=[248] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:04,425 - t=25.600 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.003 | step_counter=[256] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:04,498 - t=26.400 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.002 | step_counter=[264] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:04,561 - t=27.200 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.002 | step_counter=[272] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:04,626 - t=28.000 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.001 | step_counter=[280] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:04,697 - t=28.800 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.001 | step_counter=[288] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:04,762 - t=29.600 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.001 | step_counter=[296] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:04,826 - t=30.400 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[304] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:04,896 - t=31.200 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[312] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:04,958 - t=32.000 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[320] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:05,029 - t=32.800 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[328] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:05,106 - t=33.600 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[336] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:05,169 - t=34.400 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[344] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:05,236 - t=35.200 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[352] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:05,303 - t=36.000 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[360] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:05,365 - t=36.800 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[368] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:05,431 - t=37.600 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[376] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:05,496 - t=38.400 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[384] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:05,560 - t=39.200 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[392] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:05,632 - t=40.000 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[400] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:05,699 - t=40.800 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[408] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:05,759 - t=41.600 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[416] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:05,829 - t=42.400 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[424] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:05,895 - t=43.200 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[432] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:05,955 - t=44.000 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[440] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:06,020 - t=44.800 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[448] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:06,093 - t=45.600 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[456] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:06,154 - t=46.400 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[464] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:06,221 - t=47.200 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[472] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:06,294 - t=48.000 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[480] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:06,359 - t=48.800 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[488] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]
# 2024-12-04 17:18:06,419 - t=49.600 | pendulum_state=[ 0. -0.] | mpc_pendulum_state_control=0.000 | step_counter=[496] | robot_state=[-0.    -0.753 -0.   ] | mpc_robot_state_control=[0. 0.]

# %% [markdown]
# ## Soft Actor Critic algorithm

# %% [markdown]
# # ![SAC|width=3.67%](./gfx/sac_algo.png)

# %% [markdown]
# # ![SAC MPC|width=3.67%](./gfx/sac.png)

# %%
class Pendulum(Node):
    state = State(
        "pendulum_state",
        (2,),
        np.array([np.pi, 0]),
        _reset_modifier=lambda x: np.array(
            [
                np.random.uniform(-np.pi, np.pi),
                np.random.uniform(-1.0, 1.0),
            ]
        ),
    )
    inputs = Inputs(["actor/action", "reset_pendulum_state"])
    length = 1
    mass = 1
    gravity_acceleration = 9.81

    def system_dynamics(self, x, u):
        pendulum_mpc_control = u

        angle = x[0]
        angular_velocity = x[1]
        torque = pendulum_mpc_control

        d_angle = angular_velocity
        d_angular_velocity = self.gravity_acceleration / self.length * rg.sin(
            angle
        ) + torque / (self.mass * self.length**2)

        return {"pendulum_state": rg.vstack([d_angle, d_angular_velocity])}

    def compute_state_dynamics(self):
        pendulum_mpc_control = self.inputs["actor/action"].data

        return self.system_dynamics(self.state.data, pendulum_mpc_control)

# %%
class Observer(Node):
    state = State("observation", (3,), np.zeros(3))
    inputs = ["pendulum_state"]

    cos_max = sin_max = 1.0
    max_speed = np.inf
    observation_high = np.array([cos_max, sin_max, max_speed], dtype=np.float32)
    observation_space = gym.spaces.Box(
        low=-observation_high, high=observation_high, dtype=np.float32
    )

    def compute_state_dynamics(self) -> Dict[str, Any]:
        angle, velocity = self.inputs["pendulum_state"].data
        x = np.cos(angle)
        y = np.sin(angle)
        return {"observation": np.array([x, y, velocity])}

# %%
class RewardComputer(Node):
    def __init__(self, step_size: float = 0.1):
        state = State("reward", (1,), np.zeros(1))
        inputs = ["observation", "actor/action"]
        super().__init__(step_size=step_size, state=state, inputs=inputs)

    def compute_state_dynamics(self) -> Dict[str, Any]:
        state = self.inputs["observation"].data
        action = self.inputs["actor/action"].data

        cos_angle, sin_angle, angular_velocity = state
        angle = np.arctan2(sin_angle, cos_angle)
        position_cost = 1 * angle**2
        velocity_cost = 0.1 * angular_velocity**2
        control_cost = 0.01 * (action**2)
        reward = -(position_cost + velocity_cost + control_cost)

        return {"reward": np.array([reward])}

# %%
class ActorNetwork(nn.Module):
    def __init__(
        self,
        action_space: gym.Space,
        observation_space: gym.Space,
        log_std_min: float = -5,
        log_std_max: float = 2,
    ):
        super().__init__()
        self.fc1 = nn.Linear(np.array(observation_space.shape).prod(), 256)
        self.fc2 = nn.Linear(256, 256)
        self.fc_mean = nn.Linear(256, np.prod(action_space.shape))
        self.fc_logstd = nn.Linear(256, np.prod(action_space.shape))
        # action rescaling
        self.register_buffer(
            "action_scale",
            torch.tensor(
                (action_space.high - action_space.low) / 2.0,
                dtype=torch.float32,
            ),
        )
        self.register_buffer(
            "action_bias",
            torch.tensor(
                (action_space.high + action_space.low) / 2.0,
                dtype=torch.float32,
            ),
        )

        self.log_std_min = log_std_min
        self.log_std_max = log_std_max

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        mean = self.fc_mean(x)
        log_std = self.fc_logstd(x)
        log_std = torch.tanh(log_std)
        log_std = self.log_std_min + 0.5 * (self.log_std_max - self.log_std_min) * (
            log_std + 1
        )  # From SpinUp / Denis Yarats

        return mean, log_std

    def get_action(self, x):
        mean, log_std = self(x)
        std = log_std.exp()
        normal = torch.distributions.Normal(mean, std)
        x_t = normal.rsample()  # for reparameterization trick (mean + std * N(0,1))
        y_t = torch.tanh(x_t)
        action = y_t * self.action_scale + self.action_bias
        log_prob = normal.log_prob(x_t)
        # Enforcing Action Bound
        log_prob -= torch.log(self.action_scale * (1 - y_t.pow(2)) + 1e-6)
        log_prob = log_prob.sum(1, keepdim=True)
        mean = torch.tanh(mean) * self.action_scale + self.action_bias
        return action, log_prob, mean


class SoftQNetwork(nn.Module):
    def __init__(self, observation_space: gym.Space, action_space: gym.Space):
        super().__init__()
        self.fc1 = nn.Linear(
            np.array(observation_space.shape).prod()
            + np.array(action_space.shape).prod(),
            256,
        )
        self.fc2 = nn.Linear(256, 256)
        self.fc3 = nn.Linear(256, 1)

    def forward(self, x, a):
        x = torch.cat([x, a], 1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
class Actor(Node):
    action_shape = (1,)
    max_torque = 2.0
    action_space = gym.spaces.Box(
        low=-max_torque, high=max_torque, shape=action_shape, dtype=np.float32
    )

    def __init__(
        self,
        step_size: float = 0.01,
        device="cpu",
        learning_starts: int = 5000,
    ):
        state = State(
            "actor",
            _value=[
                State("action", shape=self.action_shape),
                State(
                    "net",
                    _value=ActorNetwork(
                        action_space=self.action_space,
                        observation_space=Observer.observation_space,
                    ).to(device),
                ),
            ],
        )
        self.device = device
        inputs = Inputs(["observation", "step_counter"])
        self.learning_starts = learning_starts
        super().__init__(step_size=step_size, state=state, inputs=inputs)

    def compute_state_dynamics(self) -> Dict[str, Any]:
        if self.inputs["step_counter"].data < self.learning_starts:
            return {"actor/action": self.action_space.sample()}
        observation = (
            torch.FloatTensor(self.inputs["observation"].data)
            .reshape(1, -1)
            .to(self.device)
        )
        with torch.no_grad():
            action, _, _ = self.state["actor/net"].data.get_action(observation)
        return {"actor/action": action.cpu().numpy().reshape(-1)}

# %%
class Buffer(Node):
    def __init__(self, buffer_size: int = int(1e6), device: str = "cpu", **kwargs):
        self.buffer = ReplayBuffer(
            buffer_size=buffer_size,
            observation_space=Observer.observation_space,
            action_space=Actor.action_space,
            device=device,
            handle_timeout_termination=False,
        )
        state = State("replay_buffer", None, self.buffer)
        inputs = ["observation", "actor/action", "reward"]
        super().__init__(state=state, inputs=inputs, **kwargs)

        # Initialize replay buffer

        self.prev_obs = None

    def compute_state_dynamics(self) -> Dict[str, Any]:
        obs = self.inputs["observation"].data.reshape(1, -1)
        action = self.inputs["actor/action"].data.reshape(1, -1)
        reward = self.inputs["reward"].data.reshape(1, -1)
        replay_buffer: ReplayBuffer = self.state["replay_buffer"].data
        if self.prev_obs is not None:
            # Add transition to buffer
            replay_buffer.add(
                obs=self.prev_obs,
                next_obs=obs,
                action=action,
                reward=reward,
                done=np.array([False]),
                infos={},
            )

        self.prev_obs = obs
        return {}

# %%
class AdaptationBlock(Node):
    def __init__(
        self,
        learning_starts: int = 5000,
        device: str = "cpu",
        autotune: bool = False,
        policy_lr: float = 0.0003,
        q_lr: float = 0.0003,
        alpha: Optional[float] = None,
        batch_size: int = 256,
        gamma: float = 0.99,
        policy_frequency: int = 2,
        target_network_frequency: int = 2,
        tau: float = 0.005,
    ):
        state = State("adaptation_block_summary", _value={})
        inputs = Inputs(["actor/net", "step_counter", "replay_buffer"])
        super().__init__(state=state, inputs=inputs)

        self.learning_starts = learning_starts
        self.device = device
        self.qf1 = SoftQNetwork(
            observation_space=Observer.observation_space,
            action_space=Actor.action_space,
        ).to(device)
        self.qf2 = SoftQNetwork(
            observation_space=Observer.observation_space,
            action_space=Actor.action_space,
        ).to(device)
        self.qf1_target = SoftQNetwork(
            observation_space=Observer.observation_space,
            action_space=Actor.action_space,
        ).to(device)
        self.qf2_target = SoftQNetwork(
            observation_space=Observer.observation_space,
            action_space=Actor.action_space,
        ).to(device)
        self.qf1_target.load_state_dict(self.qf1.state_dict())
        self.qf2_target.load_state_dict(self.qf2.state_dict())
        self.q_optimizer = optim.Adam(
            list(self.qf1.parameters()) + list(self.qf2.parameters()), lr=q_lr
        )

        self.actor_optimizer = None

        self.batch_size = batch_size
        self.gamma = gamma
        self.policy_lr = policy_lr
        self.policy_frequency = policy_frequency
        self.target_network_frequency = target_network_frequency
        self.autotune = autotune
        self.tau = tau
        # Automatic entropy tuning
        if autotune:
            self.target_entropy = -torch.prod(
                torch.Tensor(Actor.action_space.shape).to(self.device)
            ).item()
            self.log_alpha = torch.zeros(1, requires_grad=True, device=self.device)
            self.alpha = self.log_alpha.exp().item()
            self.a_optimizer = optim.Adam([self.log_alpha], lr=q_lr)
        else:
            assert alpha is not None
            self.alpha = alpha

    def compute_state_dynamics(self):
        if self.actor_optimizer is None:
            self.actor_optimizer = optim.Adam(
                list(self.inputs["actor/net"].data.parameters()), lr=self.policy_lr
            )
        if self.inputs["step_counter"].data < self.learning_starts:
            return {}

        data = self.inputs["replay_buffer"].data.sample(self.batch_size)
        with torch.no_grad():
            next_state_actions, next_state_log_pi, _ = self.inputs[
                "actor/net"
            ].data.get_action(data.observations)
            qf1_next_target = self.qf1_target(
                data.next_observations, next_state_actions
            )
            qf2_next_target = self.qf2_target(
                data.next_observations, next_state_actions
            )
            min_qf_next_target = (
                torch.min(qf1_next_target, qf2_next_target)
                - self.alpha * next_state_log_pi
            )
            next_q_value = data.rewards.flatten() + (
                1 - data.dones.flatten()
            ) * self.gamma * (min_qf_next_target).view(-1)

        qf1_a_values = self.qf1(data.observations, data.actions).view(-1)
        qf2_a_values = self.qf2(data.observations, data.actions).view(-1)
        qf1_loss = F.mse_loss(qf1_a_values, next_q_value)
        qf2_loss = F.mse_loss(qf2_a_values, next_q_value)
        qf_loss = qf1_loss + qf2_loss

        # optimize the model
        self.q_optimizer.zero_grad()
        qf_loss.backward()
        self.q_optimizer.step()

        if self.inputs["step_counter"].data % self.policy_frequency == 0:
            for _ in range(self.policy_frequency):
                pi, log_pi, _ = self.inputs["actor/net"].data.get_action(
                    data.observations
                )
                qf1_pi = self.qf1(data.observations, pi)
                qf2_pi = self.qf2(data.observations, pi)
                min_qf_pi = torch.min(qf1_pi, qf2_pi)
                actor_loss = ((self.alpha * log_pi) - min_qf_pi).mean()

                self.actor_optimizer.zero_grad()
                actor_loss.backward()
                self.actor_optimizer.step()

                if self.autotune:
                    with torch.no_grad():
                        _, log_pi, _ = self.inputs["actor/net"].data.get_action(
                            data.observations
                        )
                    alpha_loss = (
                        -self.log_alpha.exp() * (log_pi + self.target_entropy)
                    ).mean()

                self.a_optimizer.zero_grad()
                alpha_loss.backward()
                self.a_optimizer.step()
                self.alpha = self.log_alpha.exp().item()

        if self.inputs["step_counter"].data % self.target_network_frequency == 0:
            for param, target_param in zip(
                self.qf1.parameters(), self.qf1_target.parameters()
            ):
                target_param.data.copy_(
                    self.tau * param.data + (1 - self.tau) * target_param.data
                )
            for param, target_param in zip(
                self.qf2.parameters(), self.qf2_target.parameters()
            ):
                target_param.data.copy_(
                    self.tau * param.data + (1 - self.tau) * target_param.data
                )
        return {}

# %%
class PlotObservations(Node):
    def __init__(self, plot_dir: str = "plots"):
        state = State("plot_counter", (1,), np.array([0]))
        inputs = ["observation", "is_truncated", "step_counter"]
        super().__init__(state=state, inputs=inputs)
        self.observations = []

    def compute_state_dynamics(self) -> Dict[str, Any]:
        obs = self.inputs["observation"].data
        is_truncated = self.inputs["is_truncated"].data
        step = self.inputs["step_counter"].data[0]

        self.observations.append(obs)

        if is_truncated:
            import matplotlib.pyplot as plt

            plt.clf()  # Clear current figure
            clear_output()
            observations = np.array(self.observations)
            fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(10, 10))

            # Plot cos(theta)
            ax1.plot(observations[:, 0], label="cos(θ)")
            ax1.set_ylabel("cos(θ)")
            ax1.grid(True)
            ax1.legend()

            # Plot sin(theta)
            ax2.plot(observations[:, 1], label="sin(θ)")
            ax2.set_ylabel("sin(θ)")
            ax2.grid(True)
            ax2.legend()

            # Plot angular velocity
            ax3.plot(observations[:, 2], label="ω")
            ax3.set_xlabel("Step")
            ax3.set_ylabel("Angular Velocity")
            ax3.grid(True)
            ax3.legend()

            plt.tight_layout()
            plt.show()
            plt.close("all")  # Close all figures

            self.observations = []
            return {"plot_counter": self.state.data + 1}

        return {}

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
total_timesteps: int = 1000000
gamma: float = 0.99
"""the discount factor gamma"""
tau: float = 0.005
"""target smoothing coefficient (default: 0.005)"""
batch_size: int = 256
"""the batch size of sample from the reply memory"""
learning_starts: int = 5e3
"""timestep to start learning"""
policy_lr: float = 3e-4
"""the learning rate of the policy network optimizer"""
q_lr: float = 1e-3
"""the learning rate of the Q network network optimizer"""
policy_frequency: int = 2
"""the frequency of training policy (delayed)"""
target_network_frequency: int = 1  # Denis Yarats' implementation delays this by 2.
"""the frequency of updates for the target nerworks"""
alpha: float = 0.2
"""Entropy regularization coefficient."""
autotune: bool = True
"""automatic tuning of the entropy coefficient"""
# Out:
# 'automatic tuning of the entropy coefficient'

# %%
pendulum = Pendulum(is_root=True, is_continuous=True)
observer = Observer()
actor = Actor(step_size=0.05, device=device, learning_starts=learning_starts)
is_truncated = IsTruncated(steps_to_truncate=200)
reset = Reset(input_node=pendulum)
reward_computer = RewardComputer()
buffer = Buffer(device=device)
adaptation_block = AdaptationBlock(
    gamma=gamma,
    tau=tau,
    batch_size=batch_size,
    learning_starts=learning_starts,
    policy_lr=policy_lr,
    q_lr=q_lr,
    policy_frequency=policy_frequency,
    target_network_frequency=target_network_frequency,
    alpha=alpha,
    autotune=autotune,
    device=device,
)
plot_observations = PlotObservations()

graph = Graph(
    nodes=[
        pendulum,
        observer,
        actor,
        is_truncated,
        reset,
        reward_computer,
        buffer,
        adaptation_block,
        plot_observations,
    ],
    states_to_log=[
        "pendulum_state",
        "observation",
        "is_truncated",
        "step_counter",
    ],
    logger_cooldown=0.5,
)
# Out:
# Resolved node order: pendulum_state -> Clock -> step_counter -> observation -> is_truncated -> actor -> reset_pendulum_state -> plot_counter -> Logger -> reward -> replay_buffer -> adaptation_block_summary

# %%
for _ in range(total_timesteps):
    graph.step()

graph.reset()
# Out:
# 2024-12-05 12:30:03,333 - t=13540.250 | pendulum_state=[-0.559  0.124] | observation=[ 0.848 -0.53   0.124] | is_truncated=0.000 | step_counter=[270805]
# 2024-12-05 12:30:03,536 - t=13540.800 | pendulum_state=[-1.409 -3.734] | observation=[ 0.161 -0.987 -3.734] | is_truncated=0.000 | step_counter=[270816]
# 2024-12-05 12:30:03,742 - t=13541.350 | pendulum_state=[-4.335 -4.889] | observation=[-0.369  0.93  -4.889] | is_truncated=0.000 | step_counter=[270827]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[57], line 2
#       1 for _ in range(total_timesteps):
# ----> 2     graph.step()
#       4 graph.reset()
#
# File ~/Repos/regelum/regelum/environment/node/base.py:596, in Graph.step(self)
#     594 for node in self.ordered_nodes:
#     595     if node.transistor:
# --> 596         node.transistor.step()
#     597     else:
#     598         raise ValueError(f"Node {node.state.name} does not have a transistor.")
#
# File ~/Repos/regelum/regelum/environment/transistor.py:79, in Transistor.step(self)
#      76 state_updates = {}
#      78 if "default" in self.transition_map:
# ---> 79     new_state_values = self.transition_map["default"]()
#      80     state_updates.update(new_state_values)
#      81 else:
#
# Cell In[52], line 136, in AdaptationBlock.compute_state_dynamics(self)
#     132 if self.inputs["step_counter"].data % self.target_network_frequency == 0:
#     133     for param, target_param in zip(
#     134         self.qf1.parameters(), self.qf1_target.parameters()
#     135     ):
# --> 136         target_param.data.copy_(
#     137             self.tau * param.data + (1 - self.tau) * target_param.data
#     138         )
#     139     for param, target_param in zip(
#     140         self.qf2.parameters(), self.qf2_target.parameters()
#     141     ):
#     142         target_param.data.copy_(
#     143             self.tau * param.data + (1 - self.tau) * target_param.data
#     144         )
#
# KeyboardInterrupt:
